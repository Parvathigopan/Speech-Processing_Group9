# %%
from scipy.io import wavfile
from IPython.display import Audio
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
from sklearn.neural_network import MLPClassifier

# %%
# Audio processing for cat1.wav
Audio('/content/cat1.wav')
cat1, sr = librosa.load('/content/cat1.wav', duration=2.0)
cat1_train = librosa.feature.rms(y=cat1)
S = librosa.magphase(librosa.stft(cat1, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cat1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for cat2.wav
Audio('/content/cat2.wav')
cat2, sr = librosa.load('/content/cat2.wav', duration=2.0)
cat2_train = librosa.feature.rms(y=cat2)
S = librosa.magphase(librosa.stft(cat2, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cat2.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for dog1.wav
Audio('/content/dog1.wav')
dog1, sr = librosa.load('/content/dog1.wav', duration=2.0)
dog1_train = librosa.feature.rms(y=dog1)
S = librosa.magphase(librosa.stft(dog1, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy dog1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for duck1.wav
Audio('/content/duck1.wav')
duck1, sr = librosa.load('/content/duck1.wav', duration=2.0)
duck1_train = librosa.feature.rms(y=duck1)
S = librosa.magphase(librosa.stft(duck1, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy duck1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for duck2.wav
Audio('/content/duck2.wav')
duck2, sr = librosa.load('/content/duck2.wav', duration=2.0)
duck2_train = librosa.feature.rms(y=duck2)
S = librosa.magphase(librosa.stft(duck2, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy duck2.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for horse1.wav
Audio('/content/horse1.wav')
horse1, sr = librosa.load('/content/horse1.wav', duration=2.0)
horse1_train = librosa.feature.rms(y=horse1)
S = librosa.magphase(librosa.stft(horse1, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy horse1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Audio processing for horse2.wav
Audio('/content/horse2.wav')
horse2, sr = librosa.load('/content/horse2.wav', duration=2.0)
horse2_train = librosa.feature.rms(y=horse2)
S = librosa.magphase(librosa.stft(horse2, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy horse2.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Combine training data into one array
train_x = [cat1_train.ravel(), cat2_train.ravel(), dog1_train.ravel(), duck1_train.ravel(), duck2_train.ravel(), horse1_train.ravel(), horse2_train.ravel()]
train_y = np.array(['cat', 'cat', 'dog', 'duck', 'duck', 'horse', 'horse'], dtype=object)

# %%
# Train MLPClassifier
mlp = MLPClassifier()
mlp.fit(train_x, train_y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:686: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier()

# %%
# Test audio processing
Audio('/content/cat1.wav')
cat1t, sr = librosa.load('/content/cat1.wav', duration=2.0)
cat1_test = librosa.feature.rms(y=cat1t)
S = librosa.magphase(librosa.stft(cat1t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cat1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/cat3.wav')
cat3t, sr = librosa.load('/content/cat3.wav', duration=2.0)
cat3_test = librosa.feature.rms(y=cat3t)
S = librosa.magphase(librosa.stft(cat3t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cat3.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/cat4.wav')
cat4t, sr = librosa.load('/content/cat4.wav', duration=2.0)
cat4_test = librosa.feature.rms(y=cat4t)
S = librosa.magphase(librosa.stft(cat4t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cat4.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/dog2.wav')
dog2t, sr = librosa.load('/content/dog2.wav', duration=2.0)
dog2_test = librosa.feature.rms(y=dog2t)
S = librosa.magphase(librosa.stft(dog2t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy dog2.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/horse3.wav')
horse3t, sr = librosa.load('/content/horse3.wav', duration=2.0)
horse3_test = librosa.feature.rms(y=horse3t)
S = librosa.magphase(librosa.stft(horse3t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy horse3.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/cock1.wav')
cock1t, sr = librosa.load('/content/cock1.wav', duration=2.0)
cock1_test = librosa.feature.rms(y=cock1t)
S = librosa.magphase(librosa.stft(cock1t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy cock1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/goose1.wav')
gooset, sr = librosa.load('/content/goose1.wav', duration=2.0)
goose_test = librosa.feature.rms(y=gooset)
S = librosa.magphase(librosa.stft(gooset, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy goose1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/lion1.wav')
liont, sr = librosa.load('/content/lion1.wav', duration=2.0)
lion_test = librosa.feature.rms(y=liont)
S = librosa.magphase(librosa.stft(liont, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy lion1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
Audio('/content/duck1.wav')
duck1t, sr = librosa.load('/content/duck1.wav', duration=2.0)
duck1_test = librosa.feature.rms(y=duck1t)
S = librosa.magphase(librosa.stft(duck1t, window=np.ones, center=False))[0]
rms = librosa.feature.rms(S=S)
plt.figure()
plt.subplot(2, 1, 1)
plt.semilogy(rms.T, label='Average Energy duck1.wav')
plt.xticks([])
plt.xlim([0, rms.shape[-1]])
plt.legend(loc='best')
plt.subplot(2, 1, 2)
librosa.display.specshow(librosa.amplitude_to_db(S, ref=np.max), y_axis='log', x_axis='time')
plt.title('log Power spectrogram')
plt.tight_layout()

# %%
# Prepare test data for prediction
test_x = [cat1_test.ravel(), cat3_test.ravel(), cat4_test.ravel(), dog2_test.ravel(), horse3_test.ravel(), cock1_test.ravel(), goose_test.ravel(), lion_test.ravel(), duck1_test.ravel()]

# %%
# Predict the class for each test file
pred = mlp.predict(test_x)

# %%
# Mapping for predicted labels to animal names
animal_map = {
    'cat': 'Cat',
    'dog': 'Dog',
    'horse': 'Horse',
    'duck': 'Goose',
    'cock': 'Cock',
    'lion': 'Lion'
}

# %%
# Print predicted animal for each test file
for i, p in enumerate(pred):
    animal_name = animal_map.get(p, 'Unknown')
    print(f"Predicted sound is {animal_name} for test file {i+1}")
# Out:
# Predicted sound is Cat for test file 1
# Predicted sound is Cat for test file 2
# Predicted sound is Cat for test file 3
# Predicted sound is Horse for test file 4
# Predicted sound is Horse for test file 5
# Predicted sound is Goose for test file 6
# Predicted sound is Horse for test file 7
# Predicted sound is Horse for test file 8
# Predicted sound is Goose for test file 9
